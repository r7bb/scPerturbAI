# %% [markdown]
# # Perturbation Analysis
#
# PCA/UMAP structure and E-distance (energy-distance from control) per perturbation. Figures and tables here are precomputed by `scripts/02_eda.py`; see that script for the full computation.

# %%
import pandas as pd
from IPython.display import Image, display

display(Image('../results/figures/umap_control_vs_perturbed.png'))

# %%
display(Image('../results/figures/umap_top_perturbations.png'))

# %% [markdown]
# ## E-distance: which perturbations produce the strongest transcriptional shift?
#
# E-distance (scPerturb) between each perturbation's cells and control cells in PCA space; larger values indicate a stronger, more distinguishable transcriptional response.

# %%
e_dist = pd.read_csv('../results/tables/e_distance.csv')
e_dist.head(15)
# Out:
#      perturbation  e_distance
# 0       JUN_CEBPA   20.973789
# 1           CEBPA   18.762326
# 2      CEBPE_SPI1   17.317898
# 3     CEBPB_CEBPA   16.824972
# 4        IRF1_SET   14.681703
# 5     CEBPE_CEBPA   14.450053
# 6   ZC3HAV1_CEBPA   13.863969
# 7      KLF1_CEBPA   12.254012
# 8         AHR_FEV   11.581107
# 9      FOSB_CEBPB   11.566302
# 10     FOSB_CEBPE   10.593511
# 11    ZBTB10_DLX2   10.412672
# 12    FEV_CBFA2T3    9.990959
# 13    CEBPE_CEBPB    9.955959
# 14     ETS2_MAPK1    9.855543

# %%
display(Image('../results/figures/top_e_distance.png'))

# %% [markdown]
# CEBPA-driven perturbations (`JUN_CEBPA`, `CEBPA`, `CEBPB_CEBPA`, `CEBPE_CEBPA`) dominate the strongest effects — consistent with CEBPA's known role as a master regulator of myeloid differentiation.
